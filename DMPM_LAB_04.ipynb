# %% [markdown]
# <a href="https://colab.research.google.com/github/SAIOMKAR1919/DMPM_LAB/blob/main/DMPM_LAB_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **BOX PLOT**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df=sns.load_dataset("iris")
print(df.head())

sns.boxplot(y=df["sepal_length"])
plt.title("Box Plot")
plt.ylabel("Length of sepal")
plt.show()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# **SCATTER PLOT**

# %%
import pandas as pd
import matplotlib.pyplot as plt

info={
    "x":[1,5,3,8,5,1,12,6.2,9],
    "y":[30,35,40,45,50,55,60,65,70]
}
df=pd.DataFrame(info)
print(df)

plt.scatter(df['x'],df['y'])
plt.xlabel("Study Hour")
plt.ylabel("Marks")
plt.title("Study V/S Marks")
plt.show()
# Out:
#       x   y
# 0   1.0  30
# 1   5.0  35
# 2   3.0  40
# 3   8.0  45
# 4   5.0  50
# 5   1.0  55
# 6  12.0  60
# 7   6.2  65
# 8   9.0  70

# %% [markdown]
# **Histogram**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=sns.load_dataset("titanic")
print(df.head())
print(df["age"].isnull().sum())
age_info=df["age"].dropna()
plt.hist(age_info,bins=10,color='violet')
plt.xlabel("Age")
plt.ylabel("Number of passanger")
plt.title("Titanic passanger age")
plt.show()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 177

# %% [markdown]
# **Line Chart**

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    "Date":[
        "2024-01-01",
        "2024-02-01",
        "2024-03-01",
        "2024-04-01",
        "2024-05-01",
        "2024-06-01",
        "2024-07-01",
        "2024-08-01"
    ],
    "Price":[185, 192, 188, 201, 210, 218, 225, 221]
}
df=pd.DataFrame(data)
df['Date']=pd.to_datetime(df['Date'])
plt.plot(df['Date'],df['Price'],marker='o')
plt.xlabel("Date")
plt.ylabel("Price")
plt.title("Stock Price")
plt.show()

# %% [markdown]
# **Pie Chart**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=sns.load_dataset("titanic")
print(df.head())
class_count=df["pclass"].value_counts().sort_index()
print(class_count)
labels=['first class','second class','Third class']
plt.pie(
    class_count,
    labels=labels,
    startangle=90
)
plt.title("Titanic passanger class")
plt.show()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# pclass
# 1    216
# 2    184
# 3    491
# Name: count, dtype: int64

# %% [markdown]
# **Bar Plot**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df =sns.load_dataset("penguins")
avg=df.groupby("species")["body_mass_g"].mean()
plt.bar(avg.index,avg.values)
plt.xlabel("Species")
plt.ylabel("Body Mass")
plt.title("Body Mass V/S Penguins")
plt.show()
