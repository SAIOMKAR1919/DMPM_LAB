# %% [markdown]
# <a href="https://colab.research.google.com/github/SAIOMKAR1919/DMPM_LAB/blob/main/Assignment_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# WAP to find mean of the data points without using functions.

# %%
a = int(input("Enter the number of data points:"))
total = 0
for i in range(a):
  num = float(input("Enter data point:"))
  total = total+num
mean = total/a
print("Mean: ",mean)
# Out:
# Enter the number of data points:5
# Enter data point:1
# Enter data point:2
# Enter data point:3
# Enter data point:4
# Enter data point:5
# Mean:  3.0

# %% [markdown]
# WAP to print the avergae of data point with using function..

# %%
def average():
  a = int(input("Enter the number of data points: "))
  total = 0
  for i in range(a):
    num = float(input("Enter the number: "))
    total = total+num
  avg = total/a
  print("Average: ",avg)
average()
# Out:
# Enter the number of data points: 3
# Enter the number: 3
# Enter the number: 4
# Enter the number: 5
# Average:  4.0

# %% [markdown]
# WAP to find the median of data points with using functions.

# %%
def median():
  a = int(input("Enter the number of data points: "))
  data = []
  for i in range(a):
    num = float(input("Enter the number: "))
    data.append(num)
  data.sort()
  if a%2==1:
    med= data[a//2]
  else:
    med = (data[a//2-1]+data[a//2])/2
  print("Median:",med)
median()

# %% [markdown]
# WAP to find the median without using the function.

# %%
a = int(input("Enter the number of data points: "))
data = []
for i in range(a):
  num = float(input("Enter the number: "))
  data.append(num)
data.sort()
if a%2==1:
  med = data[a//2]
else:
  med = (data[n//2-1]+data[n//2])/2
print("Median: ",med)

# %% [markdown]
# WAP to find the mode of data item without using function.

# %%
a = int(input("Enter the number of data points: "))
data = []
for i in range(a):
  num = int(input("Enter number : "))
  data.append(num)
mode = data[0]
max_count = 0
for i in range(a):
  count = 0
  for j in range(a):
    if data[i] == data[j]:
      count = count+1
  if count>max_count:
    max_count = count
    mode = data[i]
print("Mode: ",mode)

# %% [markdown]
# WAP to find the mode of data item with using funnction.

# %%
def mode():
  a = int(input("Enter the number of data points: "))
  data = []
  for i in range(a):
    num = int(input("Enter the number: "))
    data.append(num)
  mode = data[0]
  max_count = 0
  for i in range(a):
    count = 0
    for j in range(a):
      if data[i] == data[j]:
        count = count+1
    if count>max_count:
      max_count = max_count
      mode = data[i]
  print("Mode: ",mode)
mode()

# %% [markdown]
# WAP to find the varience of data points with using function.

# %%
def varience():
  a = int(input("Enter the number of data points:  "))
  data = []
  for i in range(a):
    num = float(input("Enter the number: "))
    data.append(num)
  total = 0
  for i in range(a):
    total = total+data[i]
  mean = total/a
  sum_sq = 0
  for i in range(a):
    sum_sq= sum_sq+(data[i]-mean)**2
  var = sum_sq/num
  print("Mean:",mean)
  print("Varience:",var)
varience()

# %% [markdown]
# WAP to find the varience of data points without using function.

# %%
n = int(input("Enter the number of data points:"))
data = []
for i in range(n):
  num = float(input("Enter the number: "))
  data.append(num)
total = 0
for i in range(n):
  total = total+data[i]
mean = total/num
sum_sq = 0
for i in range(a):
  sum_sq = sum_sq+(data[i]-mean)**2
varience = sum_sq/num
print("Mean; ",mean)
print("Varience:",varience)

# %% [markdown]
# WAP to print standard deviation with and without function.

# %%
#with function:
def standard_deviation():
  n = int(input("Enter the number of data poitns:"))
  data = []
  for i in range(n):
    num = float(input("Entr the numbers:"))
    data.append(num)
  total = 0
  for i in range(n):
    total = total/num
    sum_sq =0
    for i in range(n):
      sum_Sq = sum_Sq+(data[i]-mean)**2
    varience = sum_Sq/num
    sd = varience**0.5
    print("Mean =", mean)
    print("Variance =", variance)
    print("Standard Deviation =", sd)
  standard_deviation()

#without functioon:
Here's a simple Python program to find the variance of data points using a function.

# WAP to find the variance of data points using a function

def variance():
    n = int(input("Enter the number of data points: "))
    data = []

    for i in range(n):
        num = float(input("Enter data point: "))
        data.append(num)

    # Calculate mean
    total = 0
    for i in range(n):
        total = total + data[i]
    mean = total / n

    # Calculate variance
    sum_sq = 0
    for i in range(n):
        sum_sq = sum_sq + (data[i] - mean) ** 2

    var = sum_sq / n

    print("Mean =", mean)
    print("Variance =", var)

variance()
Sample Output
Enter the number of data points: 5
Enter data point: 2
Enter data point: 4
Enter data point: 6
Enter data point: 8
Enter data point: 10

Mean = 6.0
Variance = 8.0

This program:

✅ Uses a user-defined function (def variance()).
✅ Does not use built-in functions like sum() or any statistics library.
✅ Calculates the mean first, then computes the variance using loops only.
WAP to find the varience of data points without using function.

Here's a simple Python program to find the variance of data points without using a user-defined function (def).

# WAP to find the variance of data points without using functions

n = int(input("Enter the number of data points: "))
data = []

for i in range(n):
    num = float(input("Enter data point: "))
    data.append(num)

# Calculate mean
total = 0
for i in range(n):
    total = total + data[i]

mean = total / n

# Calculate variance
sum_sq = 0
for i in range(n):
    sum_sq = sum_sq + (data[i] - mean) ** 2

variance = sum_sq / n

print("Mean =", mean)
print("Variance =", variance)
Sample Output
Enter the number of data points: 5
Enter data point: 2
Enter data point: 4
Enter data point: 6
Enter data point: 8
Enter data point: 10

Mean = 6.0
Variance = 8.0

Note:

✅ Does not use any user-defined function (def).
✅ Does not use sum() or the statistics module.
✅ Uses only loops, variables, and basic arithmetic, making it suitable for lab exams.
WAP to print standard deviation with and without function.

The formula for Standard Deviation is:

σ=
N
1
	​

∑
i=1
N
	​

(x
i
	​

−μ)
2
	​

The points have mean μ = 5 and σ = 1.5.
σ
σ
Drag points
1. WAP to Print Standard Deviation Using Function
# WAP to find standard deviation using function

def standard_deviation():
    n = int(input("Enter the number of data points: "))
    data = []

    for i in range(n):
        num = float(input("Enter data point: "))
        data.append(num)

    total = 0
    for i in range(n):
        total = total + data[i]

    mean = total / n

    sum_sq = 0
    for i in range(n):
        sum_sq = sum_sq + (data[i] - mean) ** 2

    variance = sum_sq / n
    sd = variance ** 0.5

    print("Mean =", mean)
    print("Variance =", variance)
    print("Standard Deviation =", sd)

standard_deviation()

# WAP to find standard deviation without using function

n = int(input("Enter the number of data points: "))
data = []
for i in range(n):
    num = float(input("Enter data point: "))
    data.append(num)
total=0
for i in range(n):
    total =total data[i]
mean =total/n
sum_sq =0
for i in range(n):
    sum_sq=sum_sq+(data[i]-mean)**2
variance=sum_sq/n
sd=variance**0.5
print("Mean =", mean)
print("Variance =", variance)
print("Standard Deviation =", sd)

# %% [markdown]
# WAP to find the varience and standard deciation of the data points entered by the user.

# %%
n =int(input("Enter the number of data points: "))
data=[]
for i in range(n):
    num =float(input("Enter data point: "))
    data.append(num)
total =0
for i in range(n):
    total =total+data[i]
mean =total/n
sum_sq =0
for i in range(n):
    sum_sq =sum_sq+(data[i]-mean)** 2
variance =sum_sq/n
standard_deviation =variance**0.5
print("Mean =",mean)
print("Variance =",variance)
print("Standard Deviation =",standard_deviation)
